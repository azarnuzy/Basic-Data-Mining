# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Dataset/covid19_sg.csv")
# to get max daily death 
p = df['Daily Deaths'].max()
p
# Out:
# 18

# %%
# to show specific identifier
ids = df.index[df['Date'] == '2021-10-20'].tolist()
df.loc[ids,:]
# Out:
#            Date  ...  Cumulative individuals using other vaccines recognised by WHO
# 636  2021-10-20  ...                                           119071.0
#
# [1 rows x 34 columns]

# %%
# to know conectivity between 'passed but not due to covid' column and  'daily death' column
df[['Passed but not due to COVID','Daily Deaths']] [df['Passed but not due to COVID'] != df['Daily Deaths']]
# Out:
#      Passed but not due to COVID  Daily Deaths
# 58                             0             2
# 66                             0             1
# 70                             0             1
# 71                             0             1
# 72                             0             1
# ..                           ...           ...
# 636                            0            18
# 637                            0            16
# 638                            0            14
# 639                            0             6
# 640                            0            15
#
# [95 rows x 2 columns]

# %%
# to get how many phases in covid 19
df.groupby(['Phase']).sum()
# Out:
#                             Daily Confirmed  ...  Cumulative individuals using other vaccines recognised by WHO
# Phase                                        ...
# Circuit Breaker                       33952  ...                                                0.0
# Phase 1                                6181  ...                                                0.0
# Phase 2                               17321  ...                                                0.0
# Phase 2 (Heightened Alert)             2955  ...                                                0.0
# Phase 3                                2787  ...                                                0.0
# Phase 3 (Heightened Alert)             1345  ...                                                0.0
# Preparatory Stage                     20117  ...                                          4018984.0
# Stabilisation Phase                   86691  ...                                          3189227.0
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
